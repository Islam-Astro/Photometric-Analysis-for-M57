# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy.wcs import WCS
from astropy.coordinates import SkyCoord
from stdpipe import plots

# %%
plt.rc('image', origin='lower', cmap='gray')

# %%
files = {
    '[B]': 'Cleaned_B_20240419_0054.fits',
    '[V]': 'Cleaned_V_20240419_0054.fits',
    '[R]': 'Cleaned_R_20240419_0054.fits',
    '[I]': 'cleanded_I_20240419_0054.fits',
    '[Hα]': 'Cleaned_Ha_M57.fits',
    '[OIII]': 'Cleaned_OIII_M57.fits'
}

# %%
# Define WCS target coordinates
target_coords = SkyCoord('18:53:34', '33:01:06', unit=('hourangle', 'deg'))

# Define the region size in pixels
region_size = {'y_min': -185, 'y_max': 50, 'x_min': -170, 'x_max': 100}

# Read FITS data and extract WCS-centered regions
data, wcs_objects = {}, {}

# %%
for filter_name, file in files.items():
    with fits.open(file) as hdul:
        wcs = WCS(hdul[0].header)
        x_center, y_center = map(int, wcs.world_to_pixel(target_coords))
        
        # Extract region around the center
        region_data = hdul[0].data[
            y_center + region_size['y_min']: y_center + region_size['y_max'],
            x_center + region_size['x_min']: x_center + region_size['x_max']
        ]
        
        data[filter_name] = region_data
        wcs_objects[filter_name] = wcs

# %%
# Define pixel scale and frame dimensions
pixscale = 0.473  # arcsec/pixel
frame_width_pixels = region_size['x_max'] - region_size['x_min']
frame_height_pixels = region_size['y_max'] - region_size['y_min']
frame_width_arcsec = frame_width_pixels * pixscale
frame_height_arcsec = frame_height_pixels * pixscale
scale_length_arcsec = frame_width_arcsec / 10
scale_length_pixels = scale_length_arcsec / pixscale

print(f"Pixel scale: {pixscale:.3f} arcsec/pixel")
print(f"Frame dimensions: {frame_width_arcsec:.1f}'' x {frame_height_arcsec:.1f}''")
print(f"Scale bar: {scale_length_arcsec:.1f}'' ({scale_length_pixels:.1f} pixels)")

# %%
# Create the plot
fig, axes = plt.subplots(2, 3, figsize=(10, 6))
filters_to_plot = ['[B]', '[V]', '[R]', '[I]', '[Hα]', '[OIII]']
labels = ['(a)', '(b)', '(c)', '(d)', '(e)', '(f)']

for ax, filter_name, label in zip(axes.flat, filters_to_plot, labels):
    plots.imshow(data[filter_name], [0.5, 99.7], interpolation='nearest', ax=ax, show_colorbar=False)
    ax.axis('off')
    ax.text(0.05, 0.9, filter_name, color='white', fontsize=10, weight='bold', transform=ax.transAxes)
    ax.text(0.95, 0.9, label, color='white', fontsize=10, ha='right', transform=ax.transAxes)

# Plot orientation arrows (N and E)
first_ax = axes[0, 0]
arrow_start = (0.9, 0.2)
arrow_length = 0.08
north_angle = np.deg2rad(177.4)
east_angle = north_angle + np.pi / 2

first_ax.arrow(arrow_start[0], arrow_start[1], arrow_length * np.sin(north_angle), arrow_length * np.cos(north_angle),
               transform=first_ax.transAxes, color='white', head_width=0.015, head_length=0.02, length_includes_head=True)
first_ax.arrow(arrow_start[0], arrow_start[1], arrow_length * np.sin(east_angle), arrow_length * np.cos(east_angle),
               transform=first_ax.transAxes, color='white', head_width=0.015, head_length=0.02, length_includes_head=True)

first_ax.text(arrow_start[0] - 0.02, arrow_start[1] - 0.05, 'N', color='white', fontsize=9, transform=first_ax.transAxes)
first_ax.text(arrow_start[0] - 0.035, arrow_start[1] - 0.015, 'E', color='white', fontsize=9, transform=first_ax.transAxes)

# Plot scale bar
scale_bar_x, scale_bar_y = 0.5, 0.9
first_ax.plot([scale_bar_x - 0.075, scale_bar_x + 0.075], [scale_bar_y, scale_bar_y],
              transform=first_ax.transAxes, color='white', lw=1)
first_ax.text(scale_bar_x, scale_bar_y + 0.02, f'{scale_length_arcsec:.1f}"', 
              color='white', fontsize=8, ha='center', transform=first_ax.transAxes)

# Frame size text
first_ax.text(0.1, 0.05, f"{frame_width_arcsec:.1f}'' x {frame_height_arcsec:.1f}''", 
              color='white', fontsize=10, ha='left', transform=first_ax.transAxes)

plt.subplots_adjust(wspace=0, hspace=0)
plt.savefig('adjusted_filters_comparison.png', dpi=300, bbox_inches='tight')
plt.show()
